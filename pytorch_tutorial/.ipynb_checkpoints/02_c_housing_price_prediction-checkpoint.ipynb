# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
RANDOM_SEED = 1

# %%
df = pd.read_csv("Housing.csv")

# %%
df.head(2)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished

# %%
encoded_data = pd.get_dummies(df,columns=['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus'])

# %%
df_categorical = ['mainroad_no', 'mainroad_yes', 'guestroom_no', 'guestroom_yes','basement_no', 'basement_yes', 'hotwaterheating_no','hotwaterheating_yes', 'airconditioning_no', 'airconditioning_yes','prefarea_no', 'prefarea_yes', 'furnishingstatus_furnished','furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished']

# %%
encoded_data[df_categorical] = encoded_data[df_categorical].astype(float)

# %%
X = encoded_data.drop(['price'],axis=1)
y = encoded_data['price']

# %%
X = torch.from_numpy(X.values).type(torch.float)
y = torch.from_numpy(y.values).type(torch.float).unsqueeze(dim=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=RANDOM_SEED)

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# torch.Size([436, 20]) torch.Size([436, 1]) torch.Size([109, 20]) torch.Size([109, 1])

# %%
X_train = X_train.to(device)
X_test = X_test.to(device)
y_train = y_train.to(device)
y_test = y_test.to(device)

# %%
class HousingPriceModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer = nn.Sequential(
            nn.Linear(in_features=20,out_features=64),
            nn.ReLU(),
            nn.Linear(in_features=64,out_features=32),
            nn.ReLU(),
            nn.Linear(in_features=32,out_features=16),
            nn.ReLU(),
            nn.Linear(in_features=16,out_features=8),
            nn.ReLU(),
            nn.Linear(in_features=8,out_features=1)
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.layer(x)

# %%
model = HousingPriceModel().to(device)
#model.state_dict()

# %%
# setup loss
loss_fn = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Training 
EPOCHS = 100000
epoch_count = []
loss_values = []
test_loss_values = []

for epoch in range(EPOCHS):
    model.train()

    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)

     # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Perform backprop wrt parameters
    loss.backward()

    # 5. step optimizer ( perform gradient descent)
    optimizer.step()

    model.eval()
    with torch.inference_mode():
        test_pred = model(X_test)
        test_loss = loss_fn(test_pred, y_test)

    if epoch % 1000 == 0:
        epoch_count.append(epoch)
        loss_values.append(loss)
        test_loss_values.append(test_loss)
        print('Epoch', epoch, 'Training Loss:', loss.item(), 'Test loss:', test_loss.item())
# Out:
# Epoch 0 Training Loss: 718474.25 Test loss: 2296870.25
# Epoch 1000 Training Loss: 708187.875 Test loss: 859731.0625
# Epoch 2000 Training Loss: 705676.3125 Test loss: 860933.125
# Epoch 3000 Training Loss: 700260.25 Test loss: 866629.375
# Epoch 4000 Training Loss: 679058.0 Test loss: 866352.5625
# Epoch 5000 Training Loss: 681010.0 Test loss: 884404.125
# Epoch 6000 Training Loss: 658740.9375 Test loss: 880894.5
# Epoch 7000 Training Loss: 646620.0 Test loss: 897254.25
# Epoch 8000 Training Loss: 634154.9375 Test loss: 916042.0625
# Epoch 9000 Training Loss: 639014.5625 Test loss: 946169.5625
# Epoch 10000 Training Loss: 630299.125 Test loss: 951919.875
# Epoch 11000 Training Loss: 621921.5625 Test loss: 891018.875
# Epoch 12000 Training Loss: 612069.3125 Test loss: 913221.875
# Epoch 13000 Training Loss: 637412.9375 Test loss: 901520.375
# Epoch 14000 Training Loss: 605639.3125 Test loss: 925639.5
# Epoch 15000 Training Loss: 581398.75 Test loss: 959353.8125
# Epoch 16000 Training Loss: 573964.8125 Test loss: 915260.125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 14
#      11 loss = loss_fn(y_pred, y_train)
#      13  # 3. Optimizer zero grad
# ---> 14 optimizer.zero_grad()
#      16 # 4. Perform backprop wrt parameters
#      17 loss.backward()
#
# File C:\datascience\projects\103_pytorch_projects\pytorch_projects\venv\lib\site-packages\torch\_compile.py:24, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def inner(*args, **kwargs):
#      22     import torch._dynamo
# ---> 24     return torch._dynamo.disable(fn, recursive)(*args, **kwargs)
#
# File C:\datascience\projects\103_pytorch_projects\pytorch_projects\venv\lib\site-packages\torch\_dynamo\decorators.py:47, in disable(fn, recursive)
#      45         fn = innermost_fn(fn)
#      46         assert callable(fn)
# ---> 47         return DisableContext()(fn)
#      48     return DisableContext()
#      49 else:
#
# File C:\datascience\projects\103_pytorch_projects\pytorch_projects\venv\lib\site-packages\torch\_dynamo\eval_frame.py:290, in _TorchDynamoContext.__call__(self, fn)
#     287 assert callable(fn)
#     289 try:
# --> 290     filename = inspect.getsourcefile(fn)
#     291 except TypeError:
#     292     filename = None
#
# File C:\datascience\python_install\lib\inspect.py:826, in getsourcefile(object)
#     823 elif any(filename.endswith(s) for s in
#     824              importlib.machinery.EXTENSION_SUFFIXES):
#     825     return None
# --> 826 if os.path.exists(filename):
#     827     return filename
#     828 # only return a non-existent filename if the module has a PEP 302 loader
#
# File C:\datascience\python_install\lib\genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
xtrain, xtest, ytrain, ytest = train_test_split(df,df['price'],test_size=0.2, random_state=RANDOM_SEED)

# %%
xtest
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 62   7070000   6240         4          2        2      yes        no       no
# 247  4550000   8400         4          1        4      yes        no       no
# 142  5600000  10500         4          2        2      yes        no       no
# 107  6125000   6420         3          1        3      yes        no      yes
# 483  2940000   6615         3          1        2      yes        no       no
# ..       ...    ...       ...        ...      ...      ...       ...      ...
# 201  4900000   4095         3          1        2       no       yes      yes
# 92   6405000   4800         3          2        4      yes       yes       no
# 66   6930000  13200         2          1        1      yes        no      yes
# 284  4270000   7770         2          1        1      yes        no       no
# 187  5110000   6100         3          1        1      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 62               no             yes        1       no        furnished
# 247              no              no        3       no      unfurnished
# 142              no              no        1       no   semi-furnished
# 107              no              no        0      yes      unfurnished
# 483              no              no        0       no   semi-furnished
# ..              ...             ...      ...      ...              ...
# 201              no             yes        0       no   semi-furnished
# 92               no             yes        0       no        furnished
# 66              yes              no        1       no        furnished
# 284              no              no        1       no        furnished
# 187              no             yes        0      yes   semi-furnished
#
# [109 rows x 13 columns]

# %%
ytest
# Out:
# 62     7070000
# 247    4550000
# 142    5600000
# 107    6125000
# 483    2940000
#         ...
# 201    4900000
# 92     6405000
# 66     6930000
# 284    4270000
# 187    5110000
# Name: price, Length: 109, dtype: int64

# %%
test_pred = model(X_test)

# %%
test_pred
# Out:
# tensor([[6236976.5000],
#         [5953892.0000],
#         [5802649.5000],
#         [5734757.0000],
#         [4229213.0000],
#         [3151382.0000],
#         [2856216.0000],
#         [7359124.5000],
#         [2787469.2500],
#         [4770251.5000],
#         [3547756.7500],
#         [3866000.0000],
#         [4888339.5000],
#         [4765624.0000],
#         [4571133.5000],
#         [7837267.0000],
#         [4307058.5000],
#         [3402633.2500],
#         [6759305.0000],
#         [2785106.2500],
#         [4135174.7500],
#         [5078390.5000],
#         [4471789.5000],
#         [3632910.0000],
#         [4712847.0000],
#         [6837272.0000],
#         [2891491.2500],
#         [6886183.0000],
#         [7008028.0000],
#         [4100365.7500],
#         [7298785.5000],
#         [6462732.0000],
#         [4057241.0000],
#         [4487408.5000],
#         [5726980.5000],
#         [4346434.5000],
#         [6164195.0000],
#         [3254943.7500],
#         [5300293.5000],
#         [5847595.5000],
#         [4404110.5000],
#         [3613491.7500],
#         [3661253.2500],
#         [4931999.0000],
#         [6606079.0000],
#         [3372966.2500],
#         [4624584.5000],
#         [2645946.7500],
#         [2774852.7500],
#         [3558926.5000],
#         [4346947.5000],
#         [4318436.5000],
#         [2769508.0000],
#         [3429669.2500],
#         [4767766.0000],
#         [4574746.0000],
#         [3387971.0000],
#         [4246980.5000],
#         [3730120.0000],
#         [4588293.0000],
#         [6260319.0000],
#         [6516133.0000],
#         [2784164.2500],
#         [4283098.0000],
#         [4427160.0000],
#         [2293701.5000],
#         [4118601.7500],
#         [3387752.2500],
#         [4142896.2500],
#         [4779054.5000],
#         [5579365.0000],
#         [5541046.0000],
#         [5514835.0000],
#         [2779976.7500],
#         [4738138.0000],
#         [3732564.2500],
#         [3381413.7500],
#         [6691433.0000],
#         [6170075.0000],
#         [3755249.0000],
#         [4636465.5000],
#         [4087720.7500],
#         [6629379.0000],
#         [5558966.0000],
#         [6604165.0000],
#         [5164932.0000],
#         [3565584.2500],
#         [2736007.7500],
#         [6286435.0000],
#         [3936617.7500],
#         [3021252.7500],
#         [4634831.0000],
#         [2829227.7500],
#         [6758402.0000],
#         [2922352.2500],
#         [5094611.0000],
#         [7659092.0000],
#         [3414697.0000],
#         [4068942.7500],
#         [5504228.5000],
#         [3177554.2500],
#         [7649899.0000],
#         [4019822.0000],
#         [3914530.0000],
#         [4730407.0000],
#         [6315799.0000],
#         [5734008.0000],
#         [3989187.7500],
#         [5669289.5000]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]
